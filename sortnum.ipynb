# %% [markdown]
# <a href="https://colab.research.google.com/github/nhimoc31231020361-cmd/nhimoc.github.io/blob/nm-pages/sortnum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = float(input("Num 1: "))
num2 = float(input("Num 2: "))

if num1 < num2:
    final1 = num1
    final2 = num2
else:
    final1 = num2
    final2 = num1

print(final1, final2)
# Out:
# Num 1: 1
# Num 2: 3
# 1.0 3.0
