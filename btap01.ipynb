# %% [markdown]
# <a href="https://colab.research.google.com/github/nhimoc31231020361-cmd/nhimoc.github.io/blob/nm-pages/btap01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
pv = 100
r = 0.1
n = 7
fv = pv * ((1 + r)**n)
print(round(fv, 2))
# Out:
# 194.87

# %%
amount = 100
interest = 10
years = 7

future_value = amount * ((1 + 0.01 * interest)**years)
print(round(future_value, 2))
# Out:
# 194.87
